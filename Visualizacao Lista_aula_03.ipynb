# %% [markdown]
# ## Lista de Exercícios - Aula 03

# %% [markdown]
# ### Explorando os dados com pandas

# %%
#importe as bibliotecas necessarias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#monte o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importe o dataset com os dados do país de sua esc

df = pd.read_excel('/content/Norway.xlsx', skiprows=20, sheet_name ='Norway by Residence')
df = df.rename(columns=df.iloc[0])[1:]
df.head()
# Out:
#    Emigrants  Both Afghanistan  935  ...   6   3  17  1
# 1  Emigrants  Both     Albania  908  ...   2  16   4  1
# 2  Emigrants  Both     Algeria  903  ...  26  28  14  5
# 3  Emigrants  Both     Andorra  908  ...   0   1   0  0
# 4  Emigrants  Both      Angola  903  ...  15  16  12  6
# 5  Emigrants  Both    Anguilla  904  ...   0   0   0  0
#
# [5 rows x 43 columns]

# %%
#remova colunas desnecessarias, mantendo as seguintes colunas: Area, Reg, Dev, Type e Coverage
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-b491097baf86> in <module>()
#       1 #remova colunas desnecessarias, mantendo as seguintes colunas: Area, Reg, Dev, Type e Coverage
#       2
# ----> 3 df.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace= True)
#       4 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# ...

# %%
#renomeie as colunas para Pais, Continente, Região e Desenvolvimento

# %%
#avalie o seu dataset e delete os anos que nao contenham valores

# %%
#adicione uma coluna chamada 'Total' que contenha a soma para todos os anos, por país

# %%
#verifique se existem nulls

# %%
# Substitua o index pelo nome dos paises para facilitar a construção das visualizações

# %% [markdown]
# ### Exercícios

# %%
# importe as bibliotecas necessarias

# %% [markdown]
# ### 1) Faça um grafico de barras com o total de imigrantes por continente

# %% [markdown]
# ### 02) Faça um grafico de area com a tendencia dos 5 países da Europa que menos contribuíram para a imigração

# %% [markdown]
# ### 3) Faça um grafico de linha com os dados dos imigrantes vindos da Nova Zelância nos anos de 1985 a 2005

# %% [markdown]
# #### 04) Compare a tendência dos países que mais contribuiram para imagraçao nos continentes Asia e Africa. (O principal país de cada continente)

# %% [markdown]
# #### 05) Faça um grafico de barras com o total de imigantes dos 3 paises que mais contribuíram para a imigração
