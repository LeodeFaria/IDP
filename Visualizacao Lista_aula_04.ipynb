# %% [markdown]
# ## Lista de Exercícios - Aula 03

# %% [markdown]
# ### Explorando os dados com pandas

# %%
#importe as bibliotecas necessarias
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
#monte o Drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#importe o dataset com os dados 
data = pd.read_csv('Copy of HR_comma_sep.csv')
data.head()
# Out:
# /gdrive/MyDrive/Colab Notebooks
# 'Cópia de 1 aula de Estatística - Exercícios de Fixação.ipynb'
# 'Cópia de 1 Aula de Estatística - Exercícios Extras (1).ipynb'
# 'Cópia de 1 Aula de Estatística - Exercícios Extras.ipynb'
# 'Cópia de 2 Aula de Estatística - Exercícios Extras.ipynb'
# 'Cópia de 2 Aula de Estatística - Exercícios Gráficos.ipynb'
# 'Cópia de 3.1 aula - Primeira lista de exercícios (aquecimento).ipynb'
# 'Cópia de 3.2 aula - Segunda lista de exercícios (com desafios).ipynb'
# 'Cópia de 3.3 aula -  Terceira Lista - Fundamentos de Python.ipynb'
# 'Cópia de 3 Aula de Estatística - Exercícios Extras.ipynb'
# 'Cópia de 4 aula - Introdução a Probabilidade - Teoria e Exercícios (1).ipynb'
# 'Cópia de 4 aula - Introdução a Probabilidade - Teoria e Exercícios.ipynb'
# 'Cópia de 5 aula - Matplotlib.ipynb'
# 'Cópia de 6 aula - EDA - Pandas Profiling (1).ipynb'
# 'Cópia de 6 aula - EDA - Pandas Profiling.ipynb'
# 'Cópia de 6 aula - Normalidade - Inferência.ipynb'
# 'Copy of HR_comma_sep.csv'
#  Trabalho.Norway
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#    satisfaction_level  last_evaluation  ...  sales  salary
# 0                0.38             0.53  ...  sales     low
# 1                0.80             0.86  ...  sales  medium
# 2                0.11             0.88  ...  sales  medium
# 3                0.72             0.87  ...  sales     low
# 4                0.37             0.52  ...  sales     low
#
# [5 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data
# Out:
#        satisfaction_level  last_evaluation  ...    sales  salary
# 0                    0.38             0.53  ...    sales     low
# 1                    0.80             0.86  ...    sales  medium
# 2                    0.11             0.88  ...    sales  medium
# 3                    0.72             0.87  ...    sales     low
# 4                    0.37             0.52  ...    sales     low
# ...                   ...              ...  ...      ...     ...
# 14994                0.40             0.57  ...  support     low
# 14995                0.37             0.48  ...  support     low
# 14996                0.37             0.53  ...  support     low
# 14997                0.11             0.96  ...  support     low
# 14998                0.37             0.52  ...  support     low
#
# [14999 rows x 10 columns]

# %% [markdown]
# ### Exercícios

# %%
# importe as bibliotecas necessarias
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
# Out:
#    satisfaction_level  last_evaluation  ...  sales  salary
# 0                0.38             0.53  ...  sales     low
# 1                0.80             0.86  ...  sales  medium
# 2                0.11             0.88  ...  sales  medium
# 3                0.72             0.87  ...  sales     low
# 4                0.37             0.52  ...  sales     low
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 1) Trabalhando com variaveis categoricas, quais insights você consegue obter?
#
# 1.   Por quantos projetos em média um colaborador é responsavel?
#
# 2.   Quanto tempo em média o colaborador fica na empresa?
# 3. Qual é o numero de empregados por setor?
# 4. E o numero de empregados por média salarial?

# %%
#1: 3.803054
#2: 3.498233
data.describe()
# Out:
#        satisfaction_level  last_evaluation  ...          left  promotion_last_5years
# count        14999.000000     14999.000000  ...  14999.000000           14999.000000
# mean             0.612834         0.716102  ...      0.238083               0.021268
# std              0.248631         0.171169  ...      0.425924               0.144281
# min              0.090000         0.360000  ...      0.000000               0.000000
# 25%              0.440000         0.560000  ...      0.000000               0.000000
# 50%              0.640000         0.720000  ...      0.000000               0.000000
# 75%              0.820000         0.870000  ...      0.000000               0.000000
# max              1.000000         1.000000  ...      1.000000               1.000000
#
# [8 rows x 8 columns]

# %%
#3:
plt.figure(figsize=(12,8))
plt.title('Contagem funcionários por Sales')
sns.countplot(x="sales", data=data)

# %%
#4:
plt.figure(figsize=(12,8))
plt.title('Contagem funcionários por Salary')
sns.countplot(x="salary", data=data)

# %% [markdown]
# ### 02) Quais são as características de quem sai da empresa? Ex: Tempo de empresa, numero de projetos, setor, salario e se recebeu promoçoes. Elabore suas conclusões.

# %%
plt.figure(figsize=(12,8))
plt.title('Ex-funcionarios/Funcionários')
sns.distplot(data.number_project[data.left == 0], bins = np.linspace(1,9,35))
sns.distplot(data.number_project[data.left == 1], bins = np.linspace(1,9,35))
plt.legend(['Former Emploees','Current Employees'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
plt.title('Ex-funcionarios/Funcionários')
sns.distplot(data.time_spend_company	[data.left == 0], bins = np.linspace(1,9,35))
sns.distplot(data.time_spend_company	[data.left == 1], bins = np.linspace(1,9,35))
plt.legend(['Former Emploees','Current Employees'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(data, hue ="left", palette ='coolwarm')

# %%
np.corrcoef([''])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e3f7daffebe8> in <module>()
#       1 plt.figure(figsize=(12,8))
#       2 plt.title('Ex-funcionarios/Funcionários')
# ----> 3 sns.distplot(data.sales [data.left == 0], bins = np.linspace(1,9,35))
#       4 sns.distplot(data.sales [data.left == 1], bins = np.linspace(1,9,35))
#       5 plt.legend(['Former Emploees','Current Employees'])
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2572
#    2573     # Make a a 1-d float array
# -> 2574     a = np.asarray(a, float)
#    2575     if a.ndim > 1:
#    2576         a = a.squeeze()
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     795               dtype='datetime64[ns]')
#     796         """
# --> 797         return np.asarray(self.array, dtype)
#     798
#     799     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     209
#     210     def __array__(self, dtype=None) -> np.ndarray:
# --> 211         return np.asarray(self._ndarray, dtype=dtype)
#     212
#     213     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'sales'

# %% [markdown]
# ### 3) E as caraterísticas de quem recebeu promoção?

# %% [markdown]
# ### 04) Sobre o tempo médio trabalhado por mês, qual é a média por setor, range de salario, tempo de empresa e numero de projetos? Quem trabalha mais ganha mais?
