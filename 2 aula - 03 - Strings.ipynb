# %% [markdown]
# ## Strings

# %% [markdown]
# ### Criando uma String
# Para criar uma string em Python você pode usar aspas simples ou duplas. Por exemplo:

# %%
# Uma única palavra
saudação = 'Oi'

# %%
saudação
# Out:
# 'Oi'

# %%
# Uma frase
'Criando uma string em Python'
# Out:
# 'Criando uma string em Python'

# %%
# Podemos usar aspas duplas
"Podemos usar aspas duplas ou simples para strings em Python"
# Out:
# 'Podemos usar aspas duplas ou simples para strings em Python'

# %%
# Você pode combinar aspas duplas e simples
"Testando strings em 'Python'"
# Out:
# "Testando strings em 'Python'"

# %% [markdown]
# ### Imprimindo uma String

# %%
print ('Testando Strings em Python')

# %%
print ('Testando \nStrings \nem \nPython')

# %%
print ('\n')

# %% [markdown]
# ### Indexando Strings

# %%
# Atribuindo uma string
s = 'A cidade de Brasília é maravilhosa'

# %%
print(s)
# Out:
# A cidade de Brasília é maravilhosa

# %%
# Primeiro elemento da string. 
s[0]
# Out:
# 'A'

# %%
s[1]
# Out:
# ' '

# %%
s[2]
# Out:
# 'c'

# %%
s[5]
# Out:
# 'a'

# %% [markdown]
# Podemos usar um : para executar um slicing que faz a leitura de tudo até um ponto designado. Por exemplo:

# %%
# Retorna todos os elementos da string, começando pela posição (lembre-se que Python começa a indexação pela posição 0),
# até o fim da string.
s[1:]
# Out:
# ' cidade de Brasília é maravilhosa'

# %%
s[:4]
# Out:
# 'A ci'

# %%
# A string original permanece inalterada
s

# %%
# Retorna tudo até a posição 3
s[:3]
# Out:
# 'A c'

# %%
s[:]

# %%
# Nós também podemos usar a indexação negativa e ler de trás para frente.
s[-1]
# Out:
# 'a'

# %%
# Retornar tudo, exceto a última letra
s[:-1]
# Out:
# 'A cidade de Brasília é maravilhos'

# %% [markdown]
# ### Propriedades de Strings

# %%
s
# Out:
# 'A cidade de Brasília é maravilhosa'

# %%
s[0]
# Out:
# 'A'

# %%
# Alterando um caracter
s[0] = 'O'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2376b993fd92> in <module>()
#       1 # Alterando um caracter
# ----> 2 s[0] = 'O'
#
# TypeError: 'str' object does not support item assignment

# %%
# Concatenando strings
s + ' e eu amo morar aqui!'
# Out:
# 'A cidade de Brasília é maravilhosa e eu amo morar aqui!'

# %%
# Podemos usar o símbolo de multiplicação para criar repetição!
letra = 'w'

# %%
letra * 30
# Out:
# 'wwwwwwwwwwwwwwwwwwwwwwwwwwwwww'

# %% [markdown]
# ### Funções Built-in de Strings

# %%
s
# Out:
# 'A cidade de Brasília é maravilhosa'

# %%
# Upper Case 
s.upper()
# Out:
# 'A CIDADE DE BRASÍLIA É MARAVILHOSA'

# %%
# Lower case
s.lower()
# Out:
# 'a cidade de brasília é maravilhosa'

# %%
# Dividir uma string por espaços em branco (padrão)
s.split()
# Out:
# ['A', 'cidade', 'de', 'Brasília', 'é', 'maravilhosa']

# %%
# Dividir uma string por um elemento específico
s.split('Brasília')
# Out:
# ['A cidade de ', ' é maravilhosa']

# %% [markdown]
# ### Funções String

# %%
s = 'seja bem vindo ao universo de python'

# %%
s.capitalize()
# Out:
# 'Seja bem vindo ao universo de python'

# %%
s.count('a')
# Out:
# 2

# %%
s.find('j')
# Out:
# 2

# %%
s.islower()
# Out:
# False

# %%
var_1 = ' J   '

# %%
var_1.isspace()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s.endswith('n')
# Out:
# True

# %% [markdown]
# ### Comparando Strings

# %%
print("Python" == "R")
# Out:
# False

# %%
print("Python" == "Python")

# %% [markdown]
# # Fim
