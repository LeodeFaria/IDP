# %% [markdown]
# ## Listas

# %%
# Criando uma lista
listadomercado = ["ovos, farinha, leite, maças"]

# %%
# Imprimindo a lista
print(listadomercado)
# Out:
# ['ovos, farinha, leite, maças']

# %%
# Criando outra lista
listadomercado2 = ["ovos" , "farinha", "leite", "maças"]

# %%
# Imprimindo a lista
print(listadomercado2)
# Out:
# ['ovos', 'farinha', 'leite', 'maças']

# %%
# Criando lista
lista3 = [12, 100, "Universidade"]

# %%
# Imprimindo
print(lista3)
# Out:
# [12, 100, 'Universidade']

# %%
lista3 = [12, 100, "Universidade"]

# %%
# Atribuindo cada valor da lista a uma variável.
item1 = lista3[0]
item2 = lista3[1]
item3 = lista3[2]

# %%
# Imprimindo as variáveis
print(item1, item2, item3)
print(item1)
# Out:
# 12 100 Universidade
# 12

# %% [markdown]
# ### Atualizando um item da lista

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças']

# %%
# Imprimindo um item da lista
listadomercado2[2]
# Out:
# 'leite'

# %%
# Atualizando um item da lista
listadomercado2[2] = "chocolate"

# %%
# Imprimindo lista alterada
listadomercado2
# Out:
# ['ovos', 'farinha', 'chocolate', 'maças']

# %% [markdown]
# ### Deletando um item da lista

# %%
# Out of index. Não é possível deletar um item que não existe na lista
del listadomercado2[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-84d96cb799fe> in <module>()
#       1 # Out of index. Não é possível deletar um item que não existe na lista
# ----> 2 del listadomercado2[4]
#
# IndexError: list assignment index out of range

# %%
# Deletando um item específico da lista
del listadomercado2[3]

# %%
# Imprimindo o item com a lista alterada
listadomercado2
# Out:
# ['ovos', 'farinha', 'chocolate']

# %% [markdown]
# ### Listas de listas (Listas aninhadas)
# Listas de listas são matrizes em Python

# %%
# Criando uma lista de listas
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
# Imprimindo a lista
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
# Atribuindo um item da lista a uma variável
a = listas[0]

# %%
a
# Out:
# [1, 2, 3]

# %%
b = a[0]

# %%
b
# Out:
# 1

# %%
list1 = listas[1]

# %%
list1
# Out:
# [10, 15, 14]

# %%
valor_1_0 = list1[0]

# %%
valor_1_0
# Out:
# 10

# %%
valor_1_2 = list1[2]

# %%
valor_1_2
# Out:
# 14

# %%
list2 = listas[2]

# %%
list2

# %%
valor_2_0 = list2[0]

# %%
valor_2_0

# %% [markdown]
# ### Operações com listas

# %%
# Criando uma lista aninhada (lista de listas)
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
# Atribuindo à variável a, o primeiro valor da primeira lista
a = listas[2][2]

# %%
a
# Out:
# 2.3

# %%
b = listas[1][2]

# %%
b
# Out:
# 14

# %%
c = listas[0][2] + 10

# %%
c
# Out:
# 13

# %%
d = 10

# %%
d
# Out:
# 10

# %%
e = d * listas[2][0]

# %%
e
# Out:
# 101.0

# %% [markdown]
# ### Concatenando listas

# %%
lista_s1 = [34, 51,32, 56]

# %%
lista_s1
# Out:
# [34, 51, 32, 56]

# %%
lista_s2 = [21, 90, 51, 51]

# %%
lista_s2
# Out:
# [21, 90, 51, 51]

# %%
# Concatenando listas
lista_total = lista_s1 + lista_s2

# %%
lista_total
# Out:
# [34, 51, 32, 56, 21, 90, 51, 51]

# %% [markdown]
# ## Operador in

# %%
# Criando uma lista
lista_teste_op = [100, 2, -5, 3.4]

# %%
# Verificando se o valor 10 pertence a lista
print(10 in lista_teste_op)
# Out:
# False

# %%
# Verificando se o valor 100 pertence a lista
print(100 in lista_teste_op)
# Out:
# True

# %%
100 in lista_teste_op
# Out:
# True

# %% [markdown]
# ## Funções Built-in

# %%
lista_teste_op
# Out:
# [100, 2, -5, 3.4]

# %%
# Função len() retorna o comprimento da lista
len(lista_teste_op)
# Out:
# 4

# %%
# Função max() retorna o valor máximo da lista
max(lista_teste_op)
# Out:
# 100

# %%
# Função min() retorna o valor mínimo da lista
min(lista_teste_op)
# Out:
# -5

# %%
# Criando uma lista
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Adicionando um item à lista
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne']

# %%
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne', 'carne']

# %%
listadomercado2.count("carne")
# Out:
# 2

# %%
# Criando uma lista vazia
a = []

# %%
print(a)
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
a.append(10)

# %%
a
# Out:
# [10]

# %%
a.append(50)

# %%
a
# Out:
# [10, 50]

# %%
old_list = [1,2,5,10]

# %%
new_list = []

# %%
# Copiando os itens de uma lista para outra
for item in old_list:
    new_list.append(item)

# %%
new_list
# Out:
# [1, 2, 5, 10]

# %%
c = [20,30]

# %%
c.append(60)

# %%
c.append(70)

# %%
c
# Out:
# [20, 30, 60, 70]

# %%
c.count(20)
# Out:
# 1

# %%
cidades = ['Recife', 'Manaus', 'Salvador']
cidades.extend(['Fortaleza', 'Palmas'])
print (cidades)
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.index('Salvador')
# Out:
# 2

# %% [markdown]
# Lembre-se: em Python o índice começa por 0!

# %%
cidades.index('Rio de Janeiro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-07703d8eb3ea> in <module>()
# ----> 1 cidades.index('Rio de Janeiro')
#
# ValueError: 'Rio de Janeiro' is not in list

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.insert(2, 'Aramina')

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Aramina', 110, 'Salvador', 'Fortaleza', 'Palmas']

# %%
# Remove um item da lista
cidades.remove(110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Aramina', 'Salvador', 'Fortaleza', 'Palmas']

# %%
# Reverte a lista
cidades.reverse()

# %%
# Imprime a lista
cidades
# Out:
# ['Palmas', 'Fortaleza', 'Salvador', 'Aramina', 'Manaus', 'Recife']

# %%
x = [3, 4, 2, 1]

# %%
x
# Out:
# [3, 4, 2, 1]

# %%
# Ordena a lista
x.sort()

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
y = ["Tijolo", "Alfabeto","Jose","Maria"]

# %%
print(y.sort())
# Out:
# None

# %% [markdown]
# # Fim
